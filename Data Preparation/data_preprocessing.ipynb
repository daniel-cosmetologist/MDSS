# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/home/djden/Development/Science/FateOfFat/MDSS/Initial Data/db_nl_preprocessed.csv')
df
# Out:
#       возраст  пол  масса_тела   рост     от     об     оп    жм    мм    ож  \
# 0        20.0    1         NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 1        20.0    0         NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 2        22.0    1         NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 3        23.0    0         NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# 4        22.0    0         NaN    NaN    NaN    NaN    NaN   NaN   NaN   NaN
# ...       ...  ...         ...    ...    ...    ...    ...   ...   ...   ...
# 2880     44.0    0       104.0  170.0  106.0  115.0    NaN  36.7   NaN  49.2
# 2881     60.0    0       180.2  174.0    NaN    NaN    NaN  99.5  45.0  60.5
# 2882     47.0    1        82.0  162.0    NaN    NaN    NaN  34.5  20.7  34.7
# 2883     45.0    0       174.8  185.0  149.7  126.0  170.0  75.4  55.6  74.3
# 2884     59.0    1        66.3  154.0   92.0   95.0   31.0  20.9  20.4  34.0
#
# ...

# %%
data_filled = df.fillna(df.mean())

# %%
data_filled
# Out:
#       возраст  пол  масса_тела       рост          от          об          оп  \
# 0        20.0    1   88.047086  167.84654   99.989344  109.849791   45.562857
# 1        20.0    0   88.047086  167.84654   99.989344  109.849791   45.562857
# 2        22.0    1   88.047086  167.84654   99.989344  109.849791   45.562857
# 3        23.0    0   88.047086  167.84654   99.989344  109.849791   45.562857
# 4        22.0    0   88.047086  167.84654   99.989344  109.849791   45.562857
# ...       ...  ...         ...        ...         ...         ...         ...
# 2880     44.0    0  104.000000  170.00000  106.000000  115.000000   45.562857
# 2881     60.0    0  180.200000  174.00000   99.989344  109.849791   45.562857
# 2882     47.0    1   82.000000  162.00000   99.989344  109.849791   45.562857
# 2883     45.0    0  174.800000  185.00000  149.700000  126.000000  170.000000
# 2884     59.0    1   66.300000  154.00000   92.000000   95.000000   31.000000
#
# ...

# %%
missing_values_remaining = data_filled.isnull().sum().sum()
missing_values_remaining
# Out:
# 0

# %%
data_filled.to_csv('/home/djden/Development/Science/FateOfFat/MDSS/Processed Data/db_nl_mean.csv')
